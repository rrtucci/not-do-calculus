# %% [markdown]
# # Frontdoor Adjustment Formula -verbose output
# ![../pics/frontdoor.jpg](../pics/frontdoor.jpg)

# %%
# this makes sure it starts looking for things from the scumpy folder down.
import os
import sys
os.chdir('../')
sys.path.insert(0,os.getcwd())
print(os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\dag_iden_detector

# %%
from DotTool import *
dot_file="dot_atlas/front-door.dot"
DotTool.draw(dot_file, jupyter=True)

# %%
from identification import *
print_all_prob_y_bar_x(dot_file=dot_file,
                       hidden_nd_names=["h"],
                       verbose=True)
# Out:
# Random bnet1:
# h, parents=[], children=['x', 'y']
# ['h']
# [0.13319451 0.39020392 0.47660158]
#
# m, parents=['x'], children=['y']
# ['x', 'm']
# [[0.64103453 0.35896547]
#  [0.04059137 0.95940863]]
#
# x, parents=['h'], children=['m']
# ['h', 'x']
# [[0.2936119  0.7063881 ]
#  [0.64511655 0.35488345]
#  [0.22908735 0.77091265]]
#
# y, parents=['h', 'm'], children=[]
# ['h', 'm', 'y']
# [[[0.14789593 0.85210407]
#   [0.32744622 0.67255378]]
#
#  [[0.14201214 0.85798786]
#   [0.73310112 0.26689888]]
#
#  [[0.35755405 0.64244595]
#   [0.43267493 0.56732507]]]
#
#
#
# full P(y|x) for bnet1:
# array([[0.34860304, 0.65139696],
#        [0.47696436, 0.52303564]])
#
# amputated P(y|x) for bnet1: (REQUIRES RCT)
# array([[0.34975376, 0.65024624],
#        [0.52410028, 0.47589972]])
#
# adjusted P(y|x) from full_pot for bnet1:
# array([[0.34975376, 0.65024624],
#        [0.52410028, 0.47589972]])
#
# adjusted P(y|x) from ampu_pot for bnet1:(REQUIRES RCT)
# array([[0.34975376, 0.65024624],
#        [0.52410028, 0.47589972]])
# ------------------------------
# Random bnet2:
# h, parents=[], children=['x', 'y']
# ['h']
# [0.3068317  0.25573689 0.43743141]
#
# m, parents=['x'], children=['y']
# ['x', 'm']
# [[0.64103453 0.35896547]
#  [0.04059137 0.95940863]]
#
# x, parents=['h'], children=['m']
# ['h', 'x']
# [[0.2936119  0.7063881 ]
#  [0.64511655 0.35488345]
#  [0.22908735 0.77091265]]
#
# y, parents=['h', 'm'], children=[]
# ['h', 'm', 'y']
# [[[0.14789593 0.85210407]
#   [0.32744622 0.67255378]]
#
#  [[0.14201214 0.85798786]
#   [0.73310112 0.26689888]]
#
#  [[0.35755405 0.64244595]
#   [0.43267493 0.56732507]]]
#
#
#
# full P(y|x) for bnet2:
# array([[0.32677878, 0.67322122],
#        [0.43216732, 0.56783268]])
#
# amputated P(y|x) for bnet2: (REQUIRES RCT)
# array([[0.32393638, 0.67606362],
#        [0.46751147, 0.53248853]])
#
# adjusted P(y|x) from full_pot for bnet2:
# array([[0.32393638, 0.67606362],
#        [0.46751147, 0.53248853]])
#
# adjusted P(y|x) from ampu_pot for bnet2:(REQUIRES RCT)
# array([[0.32393638, 0.67606362],
#        [0.46751147, 0.53248853]])
