# %% [markdown]
# # SUMMARY notebook
#
# This notebook scans the directory in which it lives to find all jupyter notebooks (other than itself) in that directory. It then prints for every notebook it finds (1) a hyperlink to the notebook, and (2) the first cell (which is always markdown) of the notebook. This way you can read a nice, automatically generated summary of all the notebooks without having to open all of them. If you find a notebook that you want to explore further, you can simply click on its link to open it.

# %%
# Version: 2
import os
import json
from IPython.display import display, Markdown

# the name of this file
this_fname = 'SUMMARY.ipynb'
fname_to_md = {}
for fname in sorted([x for x in os.listdir('./')]):
    if fname[-6:] == '.ipynb'  and fname != this_fname:
        # print('------------', fname)
        with open(fname, 'r', encoding="utf-8") as f:
            fdata = json.load(f)
            fname_to_md[fname] = ''.join(fdata['cells'][0]['source'])
# print(fname_to_md)
pre_sep = '\n\n<hr style="height:10px; background-color: blue;">\n\n'
full_md = ''
k = 1
num_nb = len(fname_to_md)
project_name ="dag_iden_detector"
who ="rrtucci"
where = "jupyter_notebooks"
for fname, md in fname_to_md.items():
    sep = pre_sep
    local_link = f' [<a href="{fname}" target= "_blank">local link</a>] '
    github_link = f' [<a href="https://github.com/{who}/{project_name}/blob/master/{where}/' +\
        f'{fname}">github link</a>] '
    sep += fname + local_link + github_link + str(k) + '/' + str(num_nb) + '\n\n'
    full_md += sep + md
    k += 1
display(Markdown(full_md))
# Out:
# <hr style="height:10px; background-color: blue;">
#
# backdoor.ipynb [<a href="backdoor.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/dag_iden_detector/blob/master/jupyter_notebooks/backdoor.ipynb">github link</a>] 1/7
#
# # Backdoor Adjusment Formula
# ![../pics/backdoor.jpg](../pics/backdoor.jpg)
#
# <hr style="height:10px; background-color: blue;">
#
# frontdoor-verbose.ipynb [<a href="frontdoor-verbose.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/dag_iden_detector/blob/master/jupyter_notebooks/frontdoor-verbose.ipynb">github link</a>] 2/7
#
# # Frontdoor Adjustment Formula -verbose output
# ![../pics/frontdoor.jpg](../pics/frontdoor.jpg)
#
# <hr style="height:10px; background-color: blue;">
#
# frontdoor.ipynb [<a href="frontdoor.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/dag_iden_detector/blob/master/jupyter_notebooks/frontdoor.ipynb">github link</a>] 3/7
#
# # Frontdoor Adjustment Formula
# ![../pics/frontdoor.jpg](../pics/frontdoor.jpg)
#
# <hr style="height:10px; background-color: blue;">
#
# napkin1-new.ipynb [<a href="napkin1-new.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/dag_iden_detector/blob/master/jupyter_notebooks/napkin1-new.ipynb">github link</a>] 4/7
#
# # Napkin Adjustment Formula 1
# ![../pics/napkin1.jpg](../pics/napkin1.jpg)
#
# <hr style="height:10px; background-color: blue;">
#
# napkin2.ipynb [<a href="napkin2.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/dag_iden_detector/blob/master/jupyter_notebooks/napkin2.ipynb">github link</a>] 5/7
#
# # Napkin Adjustment Formula 2
# ![../pics/napkin2.jpg](../pics/napkin2.jpg)
#
# <hr style="height:10px; background-color: blue;">
#
# napkin3.ipynb [<a href="napkin3.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/dag_iden_detector/blob/master/jupyter_notebooks/napkin3.ipynb">github link</a>] 6/7
#
# # Napkin Adjustment Formula 3
# ![../pics/napkin3.jpg](../pics/napkin3.jpg)
#
# <hr style="height:10px; background-color: blue;">
#
# napkin4.ipynb [<a href="napkin4.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/dag_iden_detector/blob/master/jupyter_notebooks/napkin4.ipynb">github link</a>] 7/7
#
# # Napkin Adjustment Formula 4
# ![../pics/napkin4.jpg](../pics/napkin4.jpg)
