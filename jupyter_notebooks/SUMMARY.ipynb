# %% [markdown]
# # SUMMARY notebook
#
# This notebook scans the directory in which it lives to find all jupyter notebooks (other than itself) in that directory. It then prints for every notebook it finds (1) a hyperlink to the notebook, and (2) the first cell (which is always markdown) of the notebook. This way you can read a nice, automatically generated summary of all the notebooks without having to open all of them. If you find a notebook that you want to explore further, you can simply click on its link to open it.

# %%
# Version: 2
import os
import json
from IPython.display import display, Markdown

# the name of this file
this_fname = 'SUMMARY.ipynb'
fname_to_md = {}
for fname in sorted([x for x in os.listdir('./')]):
    if fname[-6:] == '.ipynb'  and fname != this_fname:
        # print('------------', fname)
        with open(fname, 'r', encoding="utf-8") as f:
            fdata = json.load(f)
            fname_to_md[fname] = ''.join(fdata['cells'][0]['source'])
# print(fname_to_md)
pre_sep = '\n\n<hr style="height:10px; background-color: blue;">\n\n'
full_md = ''
k = 1
num_nb = len(fname_to_md)
project_name ="not-do-calculus"
who ="rrtucci"
where = "jupyter_notebooks"
for fname, md in fname_to_md.items():
    sep = pre_sep
    local_link = f' [<a href="{fname}" target= "_blank">local link</a>] '
    github_link = f' [<a href="https://github.com/{who}/{project_name}/blob/master/{where}/' +\
        f'{fname}">github link</a>] '
    sep += fname + local_link + github_link + str(k) + '/' + str(num_nb) + '\n\n'
    full_md += sep + md
    k += 1
display(Markdown(full_md))
# Out:
# <hr style="height:10px; background-color: blue;">
#
# backdoor.ipynb [<a href="backdoor.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/not-do-calculus/blob/master/jupyter_notebooks/backdoor.ipynb">github link</a>] 1/14
#
# # Backdoor Adjusment Formula
# ![../pics/backdoor.jpg](../pics/backdoor.jpg)
#
# **Proof:**
#
# This adjustment is proven VALID below.
#
# **QED**
#
# <hr style="height:10px; background-color: blue;">
#
# frontdoor-verbose.ipynb [<a href="frontdoor-verbose.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/not-do-calculus/blob/master/jupyter_notebooks/frontdoor-verbose.ipynb">github link</a>] 2/14
#
# # Frontdoor Adjustment Formula -verbose output
# ![../pics/frontdoor.jpg](../pics/frontdoor.jpg)
#
# **Proof:**
#
# This adjustment is proven VALID below.
#
# **QED**
#
# <hr style="height:10px; background-color: blue;">
#
# frontdoor.ipynb [<a href="frontdoor.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/not-do-calculus/blob/master/jupyter_notebooks/frontdoor.ipynb">github link</a>] 3/14
#
# # Frontdoor Adjustment Formula
# ![../pics/frontdoor.jpg](../pics/frontdoor.jpg)
#
# **Proof:**
#
# This adjustment is proven VALID below.
#
# **QED**
#
# <hr style="height:10px; background-color: blue;">
#
# napkin1-new.ipynb [<a href="napkin1-new.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/not-do-calculus/blob/master/jupyter_notebooks/napkin1-new.ipynb">github link</a>] 4/14
#
# # Napkin Adjustment Formula 1
# ![../pics/napkin1.jpg](../pics/napkin1.jpg)
#
# **Proof:**
#
# This adjustment is proven VALID below.
#
# **QED**
#
# <hr style="height:10px; background-color: blue;">
#
# napkin2.ipynb [<a href="napkin2.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/not-do-calculus/blob/master/jupyter_notebooks/napkin2.ipynb">github link</a>] 5/14
#
# # Napkin Adjustment Formula 2
# ![../pics/napkin2.jpg](../pics/napkin2.jpg)
#
# **Proof:**
#
# This adjustment is proven INVALID below.
#
# **QED**
#
# <hr style="height:10px; background-color: blue;">
#
# napkin3.ipynb [<a href="napkin3.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/not-do-calculus/blob/master/jupyter_notebooks/napkin3.ipynb">github link</a>] 6/14
#
# # Napkin Adjustment Formula 3
# ![../pics/napkin3.jpg](../pics/napkin3.jpg)
#
# **Proof:**
#
# This adjustment is proven INVALID below.
#
# **QED**
#
# <hr style="height:10px; background-color: blue;">
#
# napkin4.ipynb [<a href="napkin4.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/not-do-calculus/blob/master/jupyter_notebooks/napkin4.ipynb">github link</a>] 7/14
#
# # Napkin Adjustment Formula 4
# ![../pics/napkin4.jpg](../pics/napkin4.jpg)
#
# **Proof:**
#
# This adjustment is proven INVALID below.
#
# **QED**
#
# <hr style="height:10px; background-color: blue;">
#
# napkin5.ipynb [<a href="napkin5.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/not-do-calculus/blob/master/jupyter_notebooks/napkin5.ipynb">github link</a>] 8/14
#
# # Napkin Adjustment Formula 5
# ![../pics/napkin3.jpg](../pics/napkin5.jpg)
#
# **Proof:**
#
# This adjustment is proven INVALID below.
#
# **QED**
#
# <hr style="height:10px; background-color: blue;">
#
# search1-backdoor.ipynb [<a href="search1-backdoor.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/not-do-calculus/blob/master/jupyter_notebooks/search1-backdoor.ipynb">github link</a>] 9/14
#
# # Search1 back-door
# Not-Do-Calculus (NDC) can be used
# 1. to test for validity, a given adjustment formula for a given OP
# 2. (search mode) to test for validity, every member of a "plausible set" of adjustment formulae for a given OP.
#
# We provide 2 search algorithms: search1 and search2
#
# In this notebook, we use the search algorithm "search1" and the OP is the back-door bnet. search1 succeeds in finding Pearl's back-door adjustment formula.
#
# <hr style="height:10px; background-color: blue;">
#
# search1-frontdoor.ipynb [<a href="search1-frontdoor.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/not-do-calculus/blob/master/jupyter_notebooks/search1-frontdoor.ipynb">github link</a>] 10/14
#
# # Search1 front-door
# Not-Do-Calculus (NDC) can be used
# 1. to test for validity, a given adjustment formula for a given OP
# 2. (search mode) to test for validity, every member of a "plausible set" of adjustment formulae for a given OP.
#
# We provide 2 search algorithms: search1 and search2
#
# In this notebook, we use the search algorithm "search1" and the OP is the front-door bnet. search1 succeeds in finding Pearl's front-door adjustment formula.
#
# <hr style="height:10px; background-color: blue;">
#
# search1-napkin.ipynb [<a href="search1-napkin.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/not-do-calculus/blob/master/jupyter_notebooks/search1-napkin.ipynb">github link</a>] 11/14
#
# # Search1 napkin
# Not-Do-Calculus (NDC) can be used
# 1. to test for validity, a given adjustment formula for a given OP
# 2. (search mode) to test for validity, every member of a "plausible set" of adjustment formulae for a given OP
#
# We provide 2 search algorithms: search1 and search2
#
# In this notebook, we use the search algorith search1 and the OP is the napkin bnet. search1 fails to find a valid adjustment formula (such as [napkin1-new.ipynb](napkin1-new.ipynb)). However, it does  find adjustment formulae that are correct to 3 decimal places.
#
# <hr style="height:10px; background-color: blue;">
#
# search2-backdoor.ipynb [<a href="search2-backdoor.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/not-do-calculus/blob/master/jupyter_notebooks/search2-backdoor.ipynb">github link</a>] 12/14
#
# # Search2 back-door
# Not-Do-Calculus (NDC) can be used
# 1. to test for validity, a given adjustment formula for a given OP
# 2. (search mode) to test for validity, every member of a "plausible set" of adjustment formulae for a given OP
#
# We provide 2 search algorithms: search1 and search2
#
# In this notebook, we use the search algorithm search2 and the OP is the back-door bnet. search2 succeeds in finding Pearl's back-door adjustment formula.
#
# <hr style="height:10px; background-color: blue;">
#
# search2-frontdoor.ipynb [<a href="search2-frontdoor.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/not-do-calculus/blob/master/jupyter_notebooks/search2-frontdoor.ipynb">github link</a>] 13/14
#
# # Search2 front-door
# Not-Do-Calculus (NDC) can be used
# 1. to test for validity, a given adjustment formula for a given OP
# 2. (search mode) to test for validity, every member of a "plausible set" of adjustment formulae for a given OP
#
# We provide 2 search algorithms: search1 and search2
#
# In this notebook, we use the search algorithm search2 and the OP is the front-door bnet. search2 fails to find Pearl's front-door adjustment formula.
#
# <hr style="height:10px; background-color: blue;">
#
# search2-napkin.ipynb [<a href="search2-napkin.ipynb" target= "_blank">local link</a>]  [<a href="https://github.com/rrtucci/not-do-calculus/blob/master/jupyter_notebooks/search2-napkin.ipynb">github link</a>] 14/14
#
# # Search2 napkin
# Not-Do-Calculus (NDC) can be used
# 1. to test for validity, a given adjustment formula for a given OP
# 2. (search mode) to test for validity, every member of a "plausible set" of adjustment formulae for a given OP
#
# We provide 2 search algorithms: search1 and search2.
#
# In this notebook, we use the search algorithm search2 and the OP is the napkin bnet. search2 succeds in finding the valid adjustment formula of [napkin1-new.ipynb](napkin1-new.ipynb)).
